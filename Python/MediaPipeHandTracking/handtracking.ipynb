# %%
#https://techtutorialsx.com/2021/04/10/python-hand-landmark-estimation/

# %%
import cv2
import numpy as np
import mediapipe

# %%
drawingModule = mediapipe.solutions.drawing_utils
handsModule = mediapipe.solutions.hands

# %%
with handsModule.Hands(static_image_mode=True, max_num_hands = 9, min_detection_confidence = 0.001,
                      min_tracking_confidence = 0.001) as hands:
    image = cv2.imread("testimage.jpg")
    imagergb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = hands.process(imagergb)

# %%
for handLandmarks in results.multi_hand_landmarks:
      drawingModule.draw_landmarks(image, handLandmarks, handsModule.HAND_CONNECTIONS)

cv2.imshow('Test image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#hand tracking
import cv2
import mediapipe
 
drawingModule = mediapipe.solutions.drawing_utils
handsModule = mediapipe.solutions.hands
 
with handsModule.Hands(static_image_mode=True, max_num_hands = 9, min_detection_confidence = 0.001,
                      min_tracking_confidence = 0.001) as hands:
    image = cv2.imread("testimage.jpg")
    results = hands.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
     
    # Analysis of the landmarks
    imageHeight, imageWidth, _ = image.shape

# %%
#landmarkds https://google.github.io/mediapipe/solutions/hands.html#hand-landmark-model
for handLandmarks in results.multi_hand_landmarks:
    # process each hand list of landmarks
    for point in handsModule.HandLandmark:
        normalizedLandmark = handLandmarks.landmark[point]
        pixelCoordinatesLandmark = drawingModule._normalized_to_pixel_coordinates(normalizedLandmark.x, normalizedLandmark.y, imageWidth, imageHeight)
        print(point)
        print(pixelCoordinatesLandmark)
        print(normalizedLandmark)
# Out:
# HandLandmark.WRIST
# (704, 412)
# x: 0.3261766731739044
# y: 0.34053653478622437
# z: -3.113619823125191e-05
#
# HandLandmark.THUMB_CMC
# (680, 445)
# x: 0.31495195627212524
# y: 0.3682810366153717
# z: -0.0018361809197813272
#
# HandLandmark.THUMB_MCP
# (678, 482)
# x: 0.3141227960586548
# y: 0.39869365096092224
# z: -0.005229361355304718
#
# HandLandmark.THUMB_IP
# (686, 514)
# x: 0.3176995515823364
# y: 0.42491912841796875
# z: -0.005942338611930609
#
# HandLandmark.THUMB_TIP
# (689, 539)
# x: 0.31915268301963806
# y: 0.4460047483444214
# z: -0.005672508385032415
#
# HandLandmark.INDEX_FINGER_MCP
# (723, 481)
# x: 0.33476194739341736
# y: 0.3982676565647125
# z: -0.02079472690820694
#
# HandLandmark.INDEX_FINGER_PIP
# (753, 521)
# x: 0.3487623929977417
# y: 0.4309646189212799
# z: -0.02216976135969162
#
# HandLandmark.INDEX_FINGER_DIP
# (765, 542)
# x: 0.3544407784938812
# y: 0.4484197497367859
# z: -0.019393933936953545
#
# HandLandmark.INDEX_FINGER_TIP
# (769, 554)
# x: 0.3562820553779602
# y: 0.45851045846939087
# z: -0.015123127959668636
#
# HandLandmark.MIDDLE_FINGER_MCP
# (746, 464)
# x: 0.34565427899360657
# y: 0.38413992524147034
# z: -0.01627526804804802
#
# HandLandmark.MIDDLE_FINGER_PIP
# (774, 507)
# x: 0.3585914075374603
# y: 0.4192182123661041
# z: -0.0095002930611372
#
# HandLandmark.MIDDLE_FINGER_DIP
# (767, 513)
# x: 0.35519060492515564
# y: 0.42416930198669434
# z: 0.003820877056568861
#
# HandLandmark.MIDDLE_FINGER_TIP
# (755, 507)
# x: 0.349764883518219
# y: 0.41951602697372437
# z: 0.01209313701838255
#
# HandLandmark.RING_FINGER_MCP
# (762, 447)
# x: 0.35284698009490967
# y: 0.36957553029060364
# z: -0.010614155791699886
#
# HandLandmark.RING_FINGER_PIP
# (786, 484)
# x: 0.36434656381607056
# y: 0.4008066952228546
# z: -0.004530501551926136
#
# HandLandmark.RING_FINGER_DIP
# (776, 493)
# x: 0.35960817337036133
# y: 0.40777722001075745
# z: 0.006487566977739334
#
# HandLandmark.RING_FINGER_TIP
# (764, 491)
# x: 0.3540177643299103
# y: 0.40644514560699463
# z: 0.012926777824759483
#
# HandLandmark.PINKY_MCP
# (770, 431)
# x: 0.3567637801170349
# y: 0.35673192143440247
# z: -0.004263296723365784
#
# HandLandmark.PINKY_PIP
# (799, 457)
# x: 0.36996665596961975
# y: 0.3777800500392914
# z: -8.657238504383713e-05
#
# HandLandmark.PINKY_DIP
# (794, 466)
# x: 0.3677607476711273
# y: 0.38528716564178467
# z: 0.007410137914121151
#
# HandLandmark.PINKY_TIP
# (783, 469)
# x: 0.3625586926937103
# y: 0.3881915509700775
# z: 0.012808391824364662
#
# HandLandmark.WRIST
# (488, 622)
# x: 0.22619010508060455
# y: 0.514722466468811
# z: -2.3497490474255756e-05
#
# HandLandmark.THUMB_CMC
# (509, 629)
# x: 0.2358783483505249
# y: 0.5202463865280151
# z: -0.0258045494556427
#
# HandLandmark.THUMB_MCP
# (531, 643)
# x: 0.24592889845371246
# y: 0.5315014123916626
# z: -0.037962108850479126
#
# HandLandmark.THUMB_IP
# (554, 659)
# x: 0.2569039463996887
# y: 0.5449839234352112
# z: -0.0439060777425766
#
# HandLandmark.THUMB_TIP
# (578, 675)
# x: 0.2676168382167816
# y: 0.558653712272644
# z: -0.04920667037367821
#
# HandLandmark.INDEX_FINGER_MCP
# (535, 693)
# x: 0.24775852262973785
# y: 0.5730183124542236
# z: -0.02754465863108635
#
# HandLandmark.INDEX_FINGER_PIP
# (575, 707)
# x: 0.2664323151111603
# y: 0.5844080448150635
# z: -0.03184640407562256
#
# HandLandmark.INDEX_FINGER_DIP
# (591, 688)
# x: 0.2736873924732208
# y: 0.5693270564079285
# z: -0.036343950778245926
#
# HandLandmark.INDEX_FINGER_TIP
# (593, 673)
# x: 0.2746543884277344
# y: 0.5563181042671204
# z: -0.03895014896988869
#
# HandLandmark.MIDDLE_FINGER_MCP
# (536, 693)
# x: 0.24838121235370636
# y: 0.5732546448707581
# z: -0.014967527240514755
#
# HandLandmark.MIDDLE_FINGER_PIP
# (576, 705)
# x: 0.26672250032424927
# y: 0.5831253528594971
# z: -0.016163326799869537
#
# HandLandmark.MIDDLE_FINGER_DIP
# (587, 682)
# x: 0.27208301424980164
# y: 0.5640893578529358
# z: -0.019257433712482452
#
# HandLandmark.MIDDLE_FINGER_TIP
# (586, 665)
# x: 0.27140820026397705
# y: 0.5504040122032166
# z: -0.022577539086341858
#
# HandLandmark.RING_FINGER_MCP
# (537, 688)
# x: 0.2490197867155075
# y: 0.5687260031700134
# z: -0.0033690258860588074
#
# HandLandmark.RING_FINGER_PIP
# (571, 697)
# x: 0.26471227407455444
# y: 0.5763334631919861
# z: -0.0044341725297272205
#
# HandLandmark.RING_FINGER_DIP
# (579, 678)
# x: 0.26819679141044617
# y: 0.5604471564292908
# z: -0.009574336931109428
#
# HandLandmark.RING_FINGER_TIP
# (575, 663)
# x: 0.2664214074611664
# y: 0.5480916500091553
# z: -0.01353794988244772
#
# HandLandmark.PINKY_MCP
# (539, 680)
# x: 0.24971109628677368
# y: 0.5624790787696838
# z: 0.00632123788818717
#
# HandLandmark.PINKY_PIP
# (563, 688)
# x: 0.2610315680503845
# y: 0.5687606334686279
# z: 0.005685094278305769
#
# HandLandmark.PINKY_DIP
# (571, 677)
# x: 0.2647225856781006
# y: 0.5601610541343689
# z: 0.0010986800771206617
#
# HandLandmark.PINKY_TIP
# (572, 667)
# x: 0.2650260031223297
# y: 0.5514845848083496
# z: -0.0029237945564091206
#
# HandLandmark.WRIST
# (693, 473)
# x: 0.3212657868862152
# y: 0.3914070427417755
# z: 4.574096237774938e-06
#
# HandLandmark.THUMB_CMC
# (683, 488)
# x: 0.31645306944847107
# y: 0.4035392999649048
# z: -0.012319925241172314
#
# HandLandmark.THUMB_MCP
# (684, 505)
# x: 0.3171263337135315
# y: 0.4175369143486023
# z: -0.01839323341846466
#
# HandLandmark.THUMB_IP
# (689, 524)
# x: 0.31901320815086365
# y: 0.4336450695991516
# z: -0.020628610625863075
#
# HandLandmark.THUMB_TIP
# (692, 543)
# x: 0.3207925856113434
# y: 0.44916126132011414
# z: -0.02261085994541645
#
# HandLandmark.INDEX_FINGER_MCP
# (711, 513)
# x: 0.32956662774086
# y: 0.4245205819606781
# z: -0.021761871874332428
#
# HandLandmark.INDEX_FINGER_PIP
# (727, 521)
# x: 0.3367858827114105
# y: 0.4310891628265381
# z: -0.02512563392519951
#
# HandLandmark.INDEX_FINGER_DIP
# (741, 532)
# x: 0.34307801723480225
# y: 0.4401780366897583
# z: -0.028196709230542183
#
# HandLandmark.INDEX_FINGER_TIP
# (753, 542)
# x: 0.34862831234931946
# y: 0.4484476149082184
# z: -0.03092893399298191
#
# HandLandmark.MIDDLE_FINGER_MCP
# (720, 513)
# x: 0.33352795243263245
# y: 0.42471927404403687
# z: -0.015117937698960304
#
# HandLandmark.MIDDLE_FINGER_PIP
# (739, 525)
# x: 0.34241217374801636
# y: 0.4340505599975586
# z: -0.017289210110902786
#
# HandLandmark.MIDDLE_FINGER_DIP
# (750, 534)
# x: 0.34746938943862915
# y: 0.44212839007377625
# z: -0.020675137639045715
#
# HandLandmark.MIDDLE_FINGER_TIP
# (759, 541)
# x: 0.3514539301395416
# y: 0.4475289285182953
# z: -0.02322028949856758
#
# HandLandmark.RING_FINGER_MCP
# (725, 513)
# x: 0.3359599709510803
# y: 0.424315482378006
# z: -0.007823457010090351
#
# HandLandmark.RING_FINGER_PIP
# (742, 525)
# x: 0.34379538893699646
# y: 0.4340294897556305
# z: -0.010352660901844501
#
# HandLandmark.RING_FINGER_DIP
# (753, 534)
# x: 0.3490194082260132
# y: 0.4420209527015686
# z: -0.015240783803164959
#
# HandLandmark.RING_FINGER_TIP
# (763, 542)
# x: 0.35359251499176025
# y: 0.4481072425842285
# z: -0.018614130094647408
#
# HandLandmark.PINKY_MCP
# (726, 514)
# x: 0.3365496098995209
# y: 0.42505931854248047
# z: -0.0008967567118816078
#
# HandLandmark.PINKY_PIP
# (741, 522)
# x: 0.3433797359466553
# y: 0.4315689504146576
# z: -0.004840686917304993
#
# HandLandmark.PINKY_DIP
# (750, 526)
# x: 0.34738701581954956
# y: 0.43542397022247314
# z: -0.008308231830596924
#
# HandLandmark.PINKY_TIP
# (757, 530)
# x: 0.3504977524280548
# y: 0.43802696466445923
# z: -0.010149981826543808
#
# HandLandmark.WRIST
# (310, 633)
# x: 0.14362546801567078
# y: 0.5233331322669983
# z: -1.440292180632241e-05
#
# HandLandmark.THUMB_CMC
# (277, 637)
# x: 0.12825636565685272
# y: 0.5265183448791504
# z: 0.023043330758810043
#
# HandLandmark.THUMB_MCP
# (251, 643)
# x: 0.1165098175406456
# y: 0.5315978527069092
# z: 0.041439738124608994
#
# HandLandmark.THUMB_IP
# (236, 649)
# x: 0.10968416929244995
# y: 0.5365263223648071
# z: 0.055681779980659485
#
# HandLandmark.THUMB_TIP
# (227, 654)
# x: 0.10551312565803528
# y: 0.5407008528709412
# z: 0.07060706615447998
#
# HandLandmark.INDEX_FINGER_MCP
# (220, 651)
# x: 0.10193733870983124
# y: 0.5381544828414917
# z: 0.04707253724336624
#
# HandLandmark.INDEX_FINGER_PIP
# (194, 658)
# x: 0.09001625329256058
# y: 0.5439324975013733
# z: 0.06434372067451477
#
# HandLandmark.INDEX_FINGER_DIP
# (186, 658)
# x: 0.08652931451797485
# y: 0.5442786812782288
# z: 0.07271583378314972
#
# HandLandmark.INDEX_FINGER_TIP
# (182, 659)
# x: 0.08437405526638031
# y: 0.5452553033828735
# z: 0.07802703976631165
#
# HandLandmark.MIDDLE_FINGER_MCP
# (222, 652)
# x: 0.1030159667134285
# y: 0.5395035147666931
# z: 0.042070455849170685
#
# HandLandmark.MIDDLE_FINGER_PIP
# (190, 660)
# x: 0.08838949352502823
# y: 0.5457027554512024
# z: 0.06033738702535629
#
# HandLandmark.MIDDLE_FINGER_DIP
# (181, 658)
# x: 0.08422136306762695
# y: 0.543967068195343
# z: 0.07101660966873169
#
# HandLandmark.MIDDLE_FINGER_TIP
# (176, 656)
# x: 0.08171136677265167
# y: 0.542754054069519
# z: 0.08072764426469803
#
# HandLandmark.RING_FINGER_MCP
# (229, 653)
# x: 0.10622382909059525
# y: 0.5403344035148621
# z: 0.036845143884420395
#
# HandLandmark.RING_FINGER_PIP
# (202, 658)
# x: 0.0937352180480957
# y: 0.5445058345794678
# z: 0.052025552839040756
#
# HandLandmark.RING_FINGER_DIP
# (193, 654)
# x: 0.08978328108787537
# y: 0.540878415107727
# z: 0.06063053756952286
#
# HandLandmark.RING_FINGER_TIP
# (188, 652)
# x: 0.08732090145349503
# y: 0.5390680432319641
# z: 0.06828036904335022
#
# HandLandmark.PINKY_MCP
# (238, 654)
# x: 0.11053432524204254
# y: 0.5406214594841003
# z: 0.03248514607548714
#
# HandLandmark.PINKY_PIP
# (219, 655)
# x: 0.10168507695198059
# y: 0.5416181683540344
# z: 0.045282598584890366
#
# HandLandmark.PINKY_DIP
# (218, 653)
# x: 0.1010083556175232
# y: 0.5397011041641235
# z: 0.05192027986049652
#
# HandLandmark.PINKY_TIP
# (217, 652)
# x: 0.10081860423088074
# y: 0.5393693447113037
# z: 0.05811923369765282
#
# HandLandmark.WRIST
# (937, 1193)
# x: 0.433990478515625
# y: 0.986296534538269
# z: -4.8013422201620415e-05
#
# HandLandmark.THUMB_CMC
# (973, 1177)
# x: 0.45067790150642395
# y: 0.9732286930084229
# z: -0.028318271040916443
#
# HandLandmark.THUMB_MCP
# (1005, 1154)
# x: 0.46564486622810364
# y: 0.9538111090660095
# z: -0.04794318601489067
#
# HandLandmark.THUMB_IP
# (1031, 1134)
# x: 0.47744277119636536
# y: 0.9374384880065918
# z: -0.06024858355522156
#
# HandLandmark.THUMB_TIP
# (1048, 1123)
# x: 0.48551878333091736
# y: 0.9288473725318909
# z: -0.07328417152166367
#
# HandLandmark.INDEX_FINGER_MCP
# (962, 1167)
# x: 0.4457944333553314
# y: 0.9651557803153992
# z: -0.06382075697183609
#
# HandLandmark.INDEX_FINGER_PIP
# (982, 1135)
# x: 0.4549134075641632
# y: 0.9387661218643188
# z: -0.08723495155572891
#
# HandLandmark.INDEX_FINGER_DIP
# (1005, 1119)
# x: 0.4654121994972229
# y: 0.9252892732620239
# z: -0.09936952590942383
#
# HandLandmark.INDEX_FINGER_TIP
# (1023, 1107)
# x: 0.4737176299095154
# y: 0.915604829788208
# z: -0.10495105385780334
#
# HandLandmark.MIDDLE_FINGER_MCP
# (937, 1171)
# x: 0.43425458669662476
# y: 0.9679585695266724
# z: -0.0527351088821888
#
# HandLandmark.MIDDLE_FINGER_PIP
# (957, 1128)
# x: 0.4432159960269928
# y: 0.9324872493743896
# z: -0.07757217437028885
#
# HandLandmark.MIDDLE_FINGER_DIP
# (990, 1110)
# x: 0.4583747088909149
# y: 0.9174507260322571
# z: -0.0853990763425827
#
# HandLandmark.MIDDLE_FINGER_TIP
# (1018, 1097)
# x: 0.4716954231262207
# y: 0.9066807627677917
# z: -0.08992774784564972
#
# HandLandmark.RING_FINGER_MCP
# (923, 1175)
# x: 0.42749708890914917
# y: 0.9716601967811584
# z: -0.042254939675331116
#
# HandLandmark.RING_FINGER_PIP
# (940, 1132)
# x: 0.4353926181793213
# y: 0.935991644859314
# z: -0.06280309706926346
#
# HandLandmark.RING_FINGER_DIP
# (971, 1112)
# x: 0.4499744474887848
# y: 0.9191242456436157
# z: -0.06511250883340836
#
# HandLandmark.RING_FINGER_TIP
# (1000, 1099)
# x: 0.4633653461933136
# y: 0.9088809490203857
# z: -0.0655289813876152
#
# HandLandmark.PINKY_MCP
# (915, 1181)
# x: 0.4236328899860382
# y: 0.976804792881012
# z: -0.03202807530760765
#
# HandLandmark.PINKY_PIP
# (928, 1156)
# x: 0.4297228455543518
# y: 0.9555429220199585
# z: -0.044594988226890564
#
# HandLandmark.PINKY_DIP
# (944, 1141)
# x: 0.4370637834072113
# y: 0.9436260461807251
# z: -0.04500320926308632
#
# HandLandmark.PINKY_TIP
# (961, 1129)
# x: 0.4451214373111725
# y: 0.933375895023346
# z: -0.04215547442436218
#
# HandLandmark.WRIST
# (1435, 789)
# x: 0.6646507382392883
# y: 0.6525502800941467
# z: 1.387085831083823e-06
#
# HandLandmark.THUMB_CMC
# (1456, 796)
# x: 0.6743937730789185
# y: 0.6583155989646912
# z: -0.03217141702771187
#
# HandLandmark.THUMB_MCP
# (1466, 786)
# x: 0.6787333488464355
# y: 0.6498448252677917
# z: -0.05089445784687996
#
# HandLandmark.THUMB_IP
# (1458, 750)
# x: 0.6750267148017883
# y: 0.6201876997947693
# z: -0.061938442289829254
#
# HandLandmark.THUMB_TIP
# (1440, 722)
# x: 0.6670840382575989
# y: 0.5972878932952881
# z: -0.0667344257235527
#
# HandLandmark.INDEX_FINGER_MCP
# (1434, 786)
# x: 0.6642736792564392
# y: 0.6500380039215088
# z: -0.0726921334862709
#
# HandLandmark.INDEX_FINGER_PIP
# (1432, 746)
# x: 0.6631292700767517
# y: 0.6170990467071533
# z: -0.09823836386203766
#
# HandLandmark.INDEX_FINGER_DIP
# (1436, 724)
# x: 0.6649981141090393
# y: 0.5987387299537659
# z: -0.10580464452505112
#
# HandLandmark.INDEX_FINGER_TIP
# (1441, 711)
# x: 0.6672382950782776
# y: 0.5878245234489441
# z: -0.10943295806646347
#
# HandLandmark.MIDDLE_FINGER_MCP
# (1420, 770)
# x: 0.6574540734291077
# y: 0.636422336101532
# z: -0.06176711246371269
#
# HandLandmark.MIDDLE_FINGER_PIP
# (1412, 733)
# x: 0.6537366509437561
# y: 0.6059294939041138
# z: -0.08978696912527084
#
# HandLandmark.MIDDLE_FINGER_DIP
# (1416, 713)
# x: 0.6558598279953003
# y: 0.5899519920349121
# z: -0.09840723872184753
#
# HandLandmark.MIDDLE_FINGER_TIP
# (1423, 700)
# x: 0.6589071750640869
# y: 0.5786369442939758
# z: -0.1042153611779213
#
# HandLandmark.RING_FINGER_MCP
# (1410, 756)
# x: 0.6531228423118591
# y: 0.625363290309906
# z: -0.04969029873609543
#
# HandLandmark.RING_FINGER_PIP
# (1410, 721)
# x: 0.6529215574264526
# y: 0.5961225032806396
# z: -0.07297887653112411
#
# HandLandmark.RING_FINGER_DIP
# (1423, 714)
# x: 0.6588932871818542
# y: 0.5902288556098938
# z: -0.07493507862091064
#
# HandLandmark.RING_FINGER_TIP
# (1433, 712)
# x: 0.6637395024299622
# y: 0.5885009765625
# z: -0.07491838186979294
#
# HandLandmark.PINKY_MCP
# (1407, 744)
# x: 0.6516037583351135
# y: 0.6154877543449402
# z: -0.040692247450351715
#
# HandLandmark.PINKY_PIP
# (1404, 724)
# x: 0.6503058671951294
# y: 0.5987650752067566
# z: -0.05748828500509262
#
# HandLandmark.PINKY_DIP
# (1414, 718)
# x: 0.6549385190010071
# y: 0.5939952731132507
# z: -0.06713683903217316
#
# HandLandmark.PINKY_TIP
# (1424, 718)
# x: 0.6595897674560547
# y: 0.5937760472297668
# z: -0.0730600580573082
